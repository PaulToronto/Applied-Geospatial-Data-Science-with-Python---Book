# %% [markdown]
# <a href="https://colab.research.google.com/github/PaulToronto/Applied-Geospatial-Data-Science-with-Python---Book/blob/main/2_7_Folium_UI_Elements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Folium UI Elments

# %% [markdown]
# ## Imports

# %%
# !pip install vincent
# Out:
# Requirement already satisfied: vincent in /usr/local/lib/python3.10/dist-packages (0.4.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vincent) (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->vincent) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vincent) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vincent) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->vincent) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->vincent) (1.16.0)

# %%
import folium
import branca

import pandas as pd
import numpy as np

import json
import vincent

from altair import Chart

import vega_datasets

# %% [markdown]
# ## `LayerControl`

# %%
m = folium.Map(tiles=None)

folium.TileLayer('OpenStreetMap').add_to(m)
folium.TileLayer('cartodbpositron', show=False).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6dc191b822809f2a35d8959cb62ff4bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6dc191b822809f2a35d8959cb62ff4bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6dc191b822809f2a35d8959cb62ff4bc = L.map(
#                 &quot;map_6dc191b822809f2a35d8959cb62ff4bc&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84577fb2ad256f14d125bb9d5f5d6c7c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6dc191b822809f2a35d8959cb62ff4bc);
#
#
#             var tile_layer_e20e130fe49677a0469d3921c6124b6c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6dc191b822809f2a35d8959cb62ff4bc);
#
#
#             var layer_control_4761159beb4dfc939d0c241ecdadc870 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_84577fb2ad256f14d125bb9d5f5d6c7c,
#                     &quot;cartodbpositron&quot; : tile_layer_e20e130fe49677a0469d3921c6124b6c,
#                 },
#                 overlays :  {
#                 },
#             };
#             L.control.layers(
#                 layer_control_4761159beb4dfc939d0c241ecdadc870.base_layers,
#                 layer_control_4761159beb4dfc939d0c241ecdadc870.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_6dc191b822809f2a35d8959cb62ff4bc);
#             tile_layer_e20e130fe49677a0469d3921c6124b6c.remove();
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Common layer arguments
#
# - `name`: the name that appears in the layer control
# - `overlay`: `True` if the layer is an overlay
#     - `base layer`: only one can be active at a time, mostly tile layers
#     - `overlay`: multiple can be active at the same time
# - `control`: whether the layer can be controlled in the layer control
# - `show`: whether the layer will be shown when opening the map

# %% [markdown]
# ### Remove from control

# %%
m = folium.Map()

fg = folium.FeatureGroup(name='Icon collection', control=False).add_to(m)
folium.Marker(location=(0, 0)).add_to(fg)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93ce6fbe6622a56ddd010296cc38c5e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93ce6fbe6622a56ddd010296cc38c5e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93ce6fbe6622a56ddd010296cc38c5e8 = L.map(
#                 &quot;map_93ce6fbe6622a56ddd010296cc38c5e8&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cce93d01d8a60958525f5c623543704b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_93ce6fbe6622a56ddd010296cc38c5e8);
#
#
#             var feature_group_78c47d0a977e31eb236c176d6c4bca43 = L.featureGroup(
#                 {}
#             ).addTo(map_93ce6fbe6622a56ddd010296cc38c5e8);
#
#
#             var marker_a6606a4b6c11d97e75f8ce966ea7db46 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(feature_group_78c47d0a977e31eb236c176d6c4bca43);
#
#
#             var layer_control_837a577f5e06fb3305f1109df6275ca9 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_cce93d01d8a60958525f5c623543704b,
#                 },
#                 overlays :  {
#                 },
#             };
#             L.control.layers(
#                 layer_control_837a577f5e06fb3305f1109df6275ca9.base_layers,
#                 layer_control_837a577f5e06fb3305f1109df6275ca9.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_93ce6fbe6622a56ddd010296cc38c5e8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map()

fg = folium.FeatureGroup(name='Icon collection', show=False).add_to(m)
folium.Marker(location=(0, 0)).add_to(fg)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d2cf49fcbc9aa99b9675ab3657702ec7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d2cf49fcbc9aa99b9675ab3657702ec7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d2cf49fcbc9aa99b9675ab3657702ec7 = L.map(
#                 &quot;map_d2cf49fcbc9aa99b9675ab3657702ec7&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66a0478cf52f2aff168646eff514204f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d2cf49fcbc9aa99b9675ab3657702ec7);
#
#
#             var feature_group_0dac8ee4a40102182086e8ba3ac97160 = L.featureGroup(
#                 {}
#             ).addTo(map_d2cf49fcbc9aa99b9675ab3657702ec7);
#
#
#             var marker_4d07241ce75a795e3ac9387bfec8dad3 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(feature_group_0dac8ee4a40102182086e8ba3ac97160);
#
#
#             var layer_control_da07b89577f27f1251be1f4df76e3f98 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_66a0478cf52f2aff168646eff514204f,
#                 },
#                 overlays :  {
#                     &quot;Icon collection&quot; : feature_group_0dac8ee4a40102182086e8ba3ac97160,
#                 },
#             };
#             L.control.layers(
#                 layer_control_da07b89577f27f1251be1f4df76e3f98.base_layers,
#                 layer_control_da07b89577f27f1251be1f4df76e3f98.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_d2cf49fcbc9aa99b9675ab3657702ec7);
#             feature_group_0dac8ee4a40102182086e8ba3ac97160.remove();
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Popups

# %% [markdown]
# ### Simple popups
#
# - You can define your popup at the feature creation, but you can also overwrite them afterwards.

# %%
m = folium.Map([45, 0], zoom_start=4)

folium.Marker([45, -30], popup='inline implicit popup').add_to(m)

folium.CircleMarker(
    location=[45, -10],
    radius=25,
    fill=True,
    popup=folium.Popup('inline explicit Popup')
).add_to(m)

ls = folium.PolyLine(
    locations=[[43, 7], [43, 12], [47, 13], [47, 7], [43, 7]],
    color='red'
)

ls.add_child(folium.Popup('outline Popup on Polyline'))
ls.add_to(m)

gj = folium.GeoJson(
    data={
        'type': 'Polygon',
        # no, the extra brackets are not redenant
        'coordinates': [[[27, 43], [33, 43], [33, 47], [27, 47]]]
        }
    )

gj.add_child(folium.Popup('line Popup on GeoJSON'))
gj.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1e1a3804218e98028019accb170ff6f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1e1a3804218e98028019accb170ff6f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a1e1a3804218e98028019accb170ff6f = L.map(
#                 &quot;map_a1e1a3804218e98028019accb170ff6f&quot;,
#                 {
#                     center: [45.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f5fd8822195f8111801da02dced2cb47 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a1e1a3804218e98028019accb170ff6f);
#
#
#             var marker_2334ed078bad6163a2ede7a9f4b1c011 = L.marker(
#                 [45.0, -30.0],
#                 {}
#             ).addTo(map_a1e1a3804218e98028019accb170ff6f);
#
#
#         var popup_fc2045d577cf42260f688da88afcd9c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_30f9477443f569e594c7996b46dd33c7 = $(`&lt;div id=&quot;html_30f9477443f569e594c7996b46dd33c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;inline implicit popup&lt;/div&gt;`)[0];
#                 popup_fc2045d577cf42260f688da88afcd9c3.setContent(html_30f9477443f569e594c7996b46dd33c7);
#
#
#
#         marker_2334ed078bad6163a2ede7a9f4b1c011.bindPopup(popup_fc2045d577cf42260f688da88afcd9c3)
#         ;
#
#
#
#
#             var circle_marker_74099fe914af1707cbd1086828181f85 = L.circleMarker(
#                 [45.0, -10.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a1e1a3804218e98028019accb170ff6f);
#
#
#         var popup_5c49c74486598170205bfe753420fec6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3892abc5985a64b883ed694afe2704a4 = $(`&lt;div id=&quot;html_3892abc5985a64b883ed694afe2704a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;inline explicit Popup&lt;/div&gt;`)[0];
#                 popup_5c49c74486598170205bfe753420fec6.setContent(html_3892abc5985a64b883ed694afe2704a4);
#
#
#
#         circle_marker_74099fe914af1707cbd1086828181f85.bindPopup(popup_5c49c74486598170205bfe753420fec6)
#         ;
#
#
#
#
#             var poly_line_ea1393fd5c0bc258a3761939753f4587 = L.polyline(
#                 [[43.0, 7.0], [43.0, 12.0], [47.0, 13.0], [47.0, 7.0], [43.0, 7.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a1e1a3804218e98028019accb170ff6f);
#
#
#         var popup_8a3c4323070ab6184f3dcc132ff78964 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1c7d78999532f3e52e5638be851d9919 = $(`&lt;div id=&quot;html_1c7d78999532f3e52e5638be851d9919&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;outline Popup on Polyline&lt;/div&gt;`)[0];
#                 popup_8a3c4323070ab6184f3dcc132ff78964.setContent(html_1c7d78999532f3e52e5638be851d9919);
#
#
#
#         poly_line_ea1393fd5c0bc258a3761939753f4587.bindPopup(popup_8a3c4323070ab6184f3dcc132ff78964)
#         ;
#
#
#
#
#
#         function geo_json_bf83e5ac48ee98acf14a609a5997fa68_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_bf83e5ac48ee98acf14a609a5997fa68 = L.geoJson(null, {
#                 onEachFeature: geo_json_bf83e5ac48ee98acf14a609a5997fa68_onEachFeature,
#
#         });
#
#         function geo_json_bf83e5ac48ee98acf14a609a5997fa68_add (data) {
#             geo_json_bf83e5ac48ee98acf14a609a5997fa68
#                 .addData(data)
#                 .addTo(map_a1e1a3804218e98028019accb170ff6f);
#         }
#             geo_json_bf83e5ac48ee98acf14a609a5997fa68_add({&quot;coordinates&quot;: [[[27, 43], [33, 43], [33, 47], [27, 47]]], &quot;typ

# %%
m = folium.Map([45, 0], zoom_start=2)

folium.Marker(
    location=[45, -10],
    popup=folium.Popup("Let's try quotes", parse_html=True, max_width=100)
).add_to(m)

folium.Marker(
    location=[45, -30],
    popup=folium.Popup(u"Ça c'est chouette", parse_html=True, max_width='100%')
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51fed9f6929d356835c7ab8a78b1563e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51fed9f6929d356835c7ab8a78b1563e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51fed9f6929d356835c7ab8a78b1563e = L.map(
#                 &quot;map_51fed9f6929d356835c7ab8a78b1563e&quot;,
#                 {
#                     center: [45.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_60da814127390ea79fb53fc5d4fc4a12 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_51fed9f6929d356835c7ab8a78b1563e);
#
#
#             var marker_9076b2a8ea9b4d616b31d9165e9233e0 = L.marker(
#                 [45.0, -10.0],
#                 {}
#             ).addTo(map_51fed9f6929d356835c7ab8a78b1563e);
#
#
#         var popup_e73e0e587eba1708042867b05c1edb4e = L.popup({&quot;maxWidth&quot;: 100});
#
#
#
#                 var html_e6bbcb59c8d807cffa5bad924e0fb0aa = $(`&lt;div id=&quot;html_e6bbcb59c8d807cffa5bad924e0fb0aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Let&amp;#39;s try quotes&lt;/div&gt;`)[0];
#                 popup_e73e0e587eba1708042867b05c1edb4e.setContent(html_e6bbcb59c8d807cffa5bad924e0fb0aa);
#
#
#
#         marker_9076b2a8ea9b4d616b31d9165e9233e0.bindPopup(popup_e73e0e587eba1708042867b05c1edb4e)
#         ;
#
#
#
#
#             var marker_2a140a95d7468bc1363639a1a925f65a = L.marker(
#                 [45.0, -30.0],
#                 {}
#             ).addTo(map_51fed9f6929d356835c7ab8a78b1563e);
#
#
#         var popup_a29680ec4625850c2f4c4db0e463e2e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3b4eb04e7324f7fed9b82dc0097e4fa6 = $(`&lt;div id=&quot;html_3b4eb04e7324f7fed9b82dc0097e4fa6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ça c&amp;#39;est chouette&lt;/div&gt;`)[0];
#                 popup_a29680ec4625850c2f4c4db0e463e2e4.setContent(html_3b4eb04e7324f7fed9b82dc0097e4fa6);
#
#
#
#         marker_2a140a95d7468bc1363639a1a925f65a.bindPopup(popup_a29680ec4625850c2f4c4db0e463e2e4)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### HTML in popup

# %%
m = folium.Map([43, -100], zoom_start=4)

html = """
    <h1> This is a big popup</h1><br>
    With a few lines of code...
    <p>
    <code>
        from numpy import *<br>
        exp(-2*pi)
    </code>
    </p>
    """

folium.Marker([30, -100], popup=html).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d18d36dfc75cbf25ad15c8db01313e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d18d36dfc75cbf25ad15c8db01313e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d18d36dfc75cbf25ad15c8db01313e4 = L.map(
#                 &quot;map_7d18d36dfc75cbf25ad15c8db01313e4&quot;,
#                 {
#                     center: [43.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3227e642233943aca7e77786fe77cc89 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7d18d36dfc75cbf25ad15c8db01313e4);
#
#
#             var marker_66cc3c1d3e3089b6169d1b459f46738a = L.marker(
#                 [30.0, -100.0],
#                 {}
#             ).addTo(map_7d18d36dfc75cbf25ad15c8db01313e4);
#
#
#         var popup_e93fd98022f665e3cf14a7b34f3f84ac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c99f5ca94f685a850f40927af24b5fda = $(`&lt;div id=&quot;html_c99f5ca94f685a850f40927af24b5fda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;h1&gt; This is a big popup&lt;/h1&gt;&lt;br&gt;     With a few lines of code...     &lt;p&gt;     &lt;code&gt;         from numpy import *&lt;br&gt;         exp(-2*pi)     &lt;/code&gt;     &lt;/p&gt;     &lt;/div&gt;`)[0];
#                 popup_e93fd98022f665e3cf14a7b34f3f84ac.setContent(html_c99f5ca94f685a850f40927af24b5fda);
#
#
#
#         marker_66cc3c1d3e3089b6169d1b459f46738a.bindPopup(popup_e93fd98022f665e3cf14a7b34f3f84ac)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Iframe in popup

# %%
m = folium.Map([43, -100], zoom_start=4)

html = """
    <h1> This popup is an Iframe</h1><br>
    With a few lines of code...
    <p>
    <code>
        from numpy import *<br>
        exp(-2*pi)
    </code>
    </p>
    """

iframe = branca.element.IFrame(html=html, width=500, height=300)
popup = folium.Popup(iframe, max_width=500)

folium.Marker([30, -100], popup=popup).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_531256d5930950c64512d4aad683a547 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_531256d5930950c64512d4aad683a547&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_531256d5930950c64512d4aad683a547 = L.map(
#                 &quot;map_531256d5930950c64512d4aad683a547&quot;,
#                 {
#                     center: [43.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0a2efe01a37133bdb2ae88dff3b66df = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_531256d5930950c64512d4aad683a547);
#
#
#             var marker_9c63e818cdc2a677bdec60809d445957 = L.marker(
#                 [30.0, -100.0],
#                 {}
#             ).addTo(map_531256d5930950c64512d4aad683a547);
#
#
#         var popup_7863f9aaeb02710d3afb6e481e333401 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var i_frame_17ac29444dd2889eee691a2cba93760e = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICAKICAgIDxoMT4gVGhpcyBwb3B1cCBpcyBhbiBJZnJhbWU8L2gxPjxicj4KICAgIFdpdGggYSBmZXcgbGluZXMgb2YgY29kZS4uLgogICAgPHA+CiAgICA8Y29kZT4KICAgICAgICBmcm9tIG51bXB5IGltcG9ydCAqPGJyPgogICAgICAgIGV4cCgtMipwaSkKICAgIDwvY29kZT4KICAgIDwvcD4KICAgIA==&quot; width=&quot;500&quot; style=&quot;border:none !important;&quot; height=&quot;300&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_7863f9aaeb02710d3afb6e481e333401.setContent(i_frame_17ac29444dd2889eee691a2cba93760e);
#
#
#
#         marker_9c63e818cdc2a677bdec60809d445957.bindPopup(popup_7863f9aaeb02710d3afb6e481e333401)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df = pd.DataFrame(
    data=[['apple', 'orange'], ['other', 'stuff']],
    columns=['cats', 'dogs']
)

df
# Out:
#     cats    dogs
# 0  apple  orange
# 1  other   stuff

# %%
m = folium.Map([43, -100], zoom_start=4)

html = df.to_html(classes='table table-striped table-hover table-condensed table-responsive')

popup = folium.Popup(html)

folium.Marker([30, -100], popup=popup).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08a5e8e29ff797fa12577626d152b749 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08a5e8e29ff797fa12577626d152b749&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08a5e8e29ff797fa12577626d152b749 = L.map(
#                 &quot;map_08a5e8e29ff797fa12577626d152b749&quot;,
#                 {
#                     center: [43.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85d132db09f904546f04c75d55beef4b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_08a5e8e29ff797fa12577626d152b749);
#
#
#             var marker_ecca81e7bb98bfdcde4747de81d27e55 = L.marker(
#                 [30.0, -100.0],
#                 {}
#             ).addTo(map_08a5e8e29ff797fa12577626d152b749);
#
#
#         var popup_42075528dd9ff63bf1d9955b18cfb2d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_406c5bda973ecdf1a105bfd15524e5c6 = $(`&lt;div id=&quot;html_406c5bda973ecdf1a105bfd15524e5c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;table border=&quot;1&quot; class=&quot;dataframe table table-striped table-hover table-condensed table-responsive&quot;&gt;   &lt;thead&gt;     &lt;tr style=&quot;text-align: right;&quot;&gt;       &lt;th&gt;&lt;/th&gt;       &lt;th&gt;cats&lt;/th&gt;       &lt;th&gt;dogs&lt;/th&gt;     &lt;/tr&gt;   &lt;/thead&gt;   &lt;tbody&gt;     &lt;tr&gt;       &lt;th&gt;0&lt;/th&gt;       &lt;td&gt;apple&lt;/td&gt;       &lt;td&gt;orange&lt;/td&gt;     &lt;/tr&gt;     &lt;tr&gt;       &lt;th&gt;1&lt;/th&gt;       &lt;td&gt;other&lt;/td&gt;       &lt;td&gt;stuff&lt;/td&gt;     &lt;/tr&gt;   &lt;/tbody&gt; &lt;/table&gt;&lt;/div&gt;`)[0];
#                 popup_42075528dd9ff63bf1d9955b18cfb2d3.setContent(html_406c5bda973ecdf1a105bfd15524e5c6);
#
#
#
#         marker_ecca81e7bb98bfdcde4747de81d27e55.bindPopup(popup_42075528dd9ff63bf1d9955b18cfb2d3)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# create a figure with a map inside
f = branca.element.Figure()
folium.Map([-25, 150], zoom_start=3).add_to(f)

iframe = branca.element.IFrame(width=500, height=300)
f.add_to(iframe)

popup = folium.Popup(iframe, max_width=2650)

m = folium.Map([43, -100], zoom_start=4)

folium.Marker([30, -100], popup=popup).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b70b0be93b880e053a3aba69d355ba52 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b70b0be93b880e053a3aba69d355ba52&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b70b0be93b880e053a3aba69d355ba52 = L.map(
#                 &quot;map_b70b0be93b880e053a3aba69d355ba52&quot;,
#                 {
#                     center: [43.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb63ed67597c5bff7f8d223158527163 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b70b0be93b880e053a3aba69d355ba52);
#
#
#             var marker_7d18a2bd3babd60c710f13faeaf5e2a4 = L.marker(
#                 [30.0, -100.0],
#                 {}
#             ).addTo(map_b70b0be93b880e053a3aba69d355ba52);
#
#
#         var popup_f462f99f5e52f23ecc249431c09e116d = L.popup({&quot;maxWidth&quot;: 2650});
#
#
#
#                 var i_frame_8618e97f121092ada9eab187ddd9e44a = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;500&quot; style=&quot;border:none !important;&quot; height=&quot;300&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_f462f99f5e52f23ecc249431c09e116d.setContent(i_frame_8618e97f121092ada9eab187ddd9e44a);
#
#
#
#         marker_7d18a2bd3babd60c710f13faeaf5e2a4.bindPopup(popup_f462f99f5e52f23ecc249431c09e116d)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Vega chart in popup

# %%
multi_iter2 = {
    'x': np.random.uniform(size=(100, )),
    'y': np.random.uniform(size=(100, ))
}

multi_iter2
# Out:
# {'x': array([0.06383444, 0.45405919, 0.68966889, 0.16689744, 0.70253856,
#         0.14685801, 0.18857029, 0.07420837, 0.28289967, 0.16826808,
#         0.74540437, 0.69189384, 0.74280132, 0.11760669, 0.01487664,
#         0.61039505, 0.93777122, 0.48305018, 0.43757903, 0.54876119,
#         0.91373832, 0.42936816, 0.4564352 , 0.40683913, 0.96889997,
#         0.83434311, 0.5025827 , 0.62475319, 0.34334302, 0.24608815,
#         0.14705391, 0.46374415, 0.3377795 , 0.59021219, 0.16137405,
#         0.46186508, 0.68940258, 0.98698231, 0.17270829, 0.86170933,
#         0.98551894, 0.19420232, 0.08601337, 0.27201911, 0.60350901,
#         0.60285794, 0.8952129 , 0.44083723, 0.96553428, 0.50510858,
#         0.36248939, 0.8000207 , 0.71999968, 0.15846796, 0.16738061,
#         0.05294863, 0.86310016, 0.71190477, 0.41697783, 0.99262295,
#         0.6065403 , 0.33384182, 0.74808828, 0.00561407, 0.07856007,
#         0.01799052, 0.58181731, 0.05426686, 0.87092206, 0.01304407,
#         0.15667517, 0.35403816, 0.39110503, 0.37325945, 0.84883327,
#         0.83285092, 0.60553853, 0.91938956, 0.88017561, 0.6844296 ,
#         0.9660597 , 0.38748857, 0.50705609, 0.08895712, 0.24752981,
#         0.12120952, 0.74124782, 0.01893265, 0.9942161 , 0.14998657,
#         0.69783055, 0.2565744 , 0.86933812, 0.20905609, 0.61231849,
#         0.53211291, 0.75373343, 0.30913859, 0.64718163, 0.93748269]),
#  'y': array([8.15318663e-01, 6.57116390e-01, 1.50134445e-01, 9.52288459e-01,
#         3.33940134e-01, 9.89596927e-01, 1.79579661e-01, 8.30487827e-01,
#         8.67079061e-01, 3.82658892e-01, 4.98013799e-01, 7.35604834e-01,
#         6.34895849e-01, 6.86458742e-01, 8.77979017e-01, 4.50280307e-01,
#         7.05521697e-01, 7.35017233e-02, 5.88725628e-01, 2.68198965e-01,
#         6.25897823e-01, 7.55068901e-02, 1.59116184e-01, 6.62239385e-01,
#         2.08248616e-01, 3.75306659e-01, 9.48995406e-01, 5.32415773e-01,
#         5.17278068e-01, 1.02877913e-01, 8.41063831e-01, 9.76001949e-01,
#         9.91467131e-02, 4.78278254e-01, 4.95425458e-01, 3.57341176e-02,
#         2.27437830e-01, 6.68908184e-01, 3.12892520e-02, 2.56258802e-01,
#         1.73261529e-02, 2.79876863e-01, 1.66355122e-01, 6.60793758e-01,
#         8.27434788e-04, 3.88053751e-01, 6.91410118e-01, 1.29074341e-01,
#         5.31706368e-01, 3.56555633e-01, 5.34660984e-02, 3.30752592e-01,
#         6.22598492e-01, 9.69469998e-01, 4.99643906e-01, 3.60628626e-01,
#         1.63195356e-02, 8.35356611e-01, 4.88489890e-01, 5.50460287e-01,
#         2.13555129e-01, 7.68800319e-01, 3.02694196e-01, 9.43877507e-01,
#         3.43024814e-01, 4.25740590e-01, 5.09448408e-01, 6.10879431e-01,
#         6.21100562e-02, 3.42515734e-01, 4.56890014e-01, 4.00735061e-01,
#         4.54886744e-02, 6.89029169e-01, 3.51780458e-01, 8.36811080e-01,
#         4.03218580e-01, 6.01115628e-01, 4.77687060e-01, 6.55283975e-02,
#         1.30920795e-01, 7.84394467e-01, 7.75686460e-01, 8.38356653e-01,
#         1.30206390e-01, 7.80036299e-01, 3.45532629e-01, 4.85928485e-01,
#         8.89047833e-01, 7.93369899e-01, 2.49233322e-02, 2.06425349e-01,
#         4.10312328e-01, 5.81124289e-01, 7.20901271e-01, 5.42773408e-01,
#         4.59430804e-01, 2.19050009e-01, 6.89460111e-01, 4.56985000e-01])}

# %%
scatter = vincent.Scatter(multi_iter2, iter_idx='x', height=100, width=200)
data = json.loads(scatter.to_json())
data
# Out:
# {'axes': [{'scale': 'x', 'type': 'x'}, {'scale': 'y', 'type': 'y'}],
#  'data': [{'name': 'table',
#    'values': [{'col': 'y',
#      'idx': 0.06383443615310558,
#      'val': 0.8153186625723461},
#     {'col': 'y', 'idx': 0.4540591918492206, 'val': 0.6571163895553634},
#     {'col': 'y', 'idx': 0.6896688875570728, 'val': 0.15013444480188132},
#     {'col': 'y', 'idx': 0.1668974385925398, 'val': 0.9522884586905292},
#     {'col': 'y', 'idx': 0.7025385623658056, 'val': 0.33394013358031915},
#     {'col': 'y', 'idx': 0.1468580071397192, 'val': 0.9895969271364038},
#     {'col': 'y', 'idx': 0.18857028650178675, 'val': 0.17957966055783137},
#     {'col': 'y', 'idx': 0.07420836523760477, 'val': 0.8304878267979785},
#     {'col': 'y', 'idx': 0.2828996743338428, 'val': 0.867079060928203},
#     {'col': 'y', 'idx': 0.16826808472578625, 'val': 0.38265889153811683},
#     {'col': 'y', 'idx': 0.7454043652204321, 'val': 0.49801379851866523},
#     {'col': 'y', 'idx': 0.6918938437182678, 'val': 0.735604833695835},
#     {'col': 'y', 'idx': 0.7428013199056022, 'val': 0.6348958485837621},
#     {'col': 'y', 'idx': 0.11760668662734708, 'val': 0.6864587417505902},
#     {'col': 'y', 'idx': 0.014876640370163896, 'val': 0.8779790167604002},
#     {'col': 'y', 'idx': 0.6103950510059409, 'val': 0.45028030683821696},
#     {'col': 'y', 'idx': 0.9377712158918619, 'val': 0.7055216967422538},
#     {'col': 'y', 'idx': 0.48305018087884066, 'val': 0.07350172334173932},
#     {'col': 'y', 'idx': 0.43757902875978627, 'val': 0.5887256276354502},
#     {'col': 'y', 'idx': 0.5487611864127908, 'val': 0.2681989654843494},
#     {'col': 'y', 'idx': 0.9137383214754878, 'val': 0.6258978234457085},
#     {'col': 'y', 'idx': 0.4293681573968432, 'val': 0.07550689012248213},
#     {'col': 'y', 'idx': 0.45643520260517045, 'val': 0.1591161839927483},
#     {'col': 'y', 'idx': 0.4068391321908863, 'val': 0.662239385450004},
#     {'col': 'y', 'idx': 0.9688999675314199, 'val': 0.20824861649694937},
#     {'col': 'y', 'idx': 0.8343431100437032, 'val': 0.37530665901720195},
#     {'col': 'y', 'idx': 0.5025826982399565, 'val': 0.9489954058629124},
#     {'col': 'y', 'idx': 0.6247531853097497, 'val': 0.5324157731707648},
#     {'col': 'y', 'idx': 0.3433430158451184, 'val': 0.5172780676739933},
#     {'col': 'y', 'idx': 0.24608815307231058, 'val': 0.10287791319887862},
#     {'col': 'y', 'idx': 0.14705391252889577, 'val': 0.8410638313183486},
#     {'col': 'y', 'idx': 0.46374415358182874, 'val': 0.976001948702544},
#     {'col': 'y', 'idx': 0.33777949777675986, 'val': 0.09914671311038525},
#     {'col': 'y', 'idx': 0.5902121921739962, 'val': 0.4782782539300171},
#     {'col': 'y', 'idx': 0.16137404829415314, 'val': 0.4954254576644658},
#     {'col': 'y', 'idx': 0.46186508354302946, 'val': 0.035734117551507016},
#     {'col': 'y', 'idx': 0.6894025790954402, 'val': 0.22743783017642238},
#     {'col': 'y', 'idx': 0.9869823114005739, 'val': 0.6689081844769602},
#     {'col': 'y', 'idx': 0.1727082925792377, 'val': 0.03128925196312271},
#     {'col': 'y', 'idx': 0.8617093269828713, 'val': 0.25625880187386374},
#     {'col': 'y', 'idx': 0.9855189399175126, 'val': 0.017326152932061745},
#     {'col': 'y', 'idx': 0.1942023232380643, 'val': 0.2798768633713822},
#     {'col': 'y', 'idx': 0.08601337215442628, 'val': 0.16635512203910907},
#     {'col': 'y', 'idx': 0.2720191115562256, 'val': 0.6607937577945313},
#     {'col': 'y', 'idx': 0.6035090148756552, 'val': 0.0008274347882167854},
#     {'col': 'y', 'idx': 0.6028579380348369, 'val': 0.38805375081898785},
#     {'col': 'y', 'idx': 0.8952128974501263, 'val': 0.6914101183869614},
#     {'col': 'y', 'idx': 0.44083722667097003, 'val': 0.1290743412848323},
#     {'col': 'y', 'idx': 0.9655342783034245, 'val': 0.5317063680133816},
#     {'col': 'y', 'idx': 0.5051085788360157, 'val': 0.35655563328958373},
#     {'col': 'y', 'idx': 0.36248938687533705, 'val': 0.053466098381789395},
#     {'col': 'y', 'idx': 0.8000207027533031, 'val': 0.33075259180321426},
#     {'col': 'y', 'idx': 0.7199996780059302, 'val': 0.6225984920074346},
#     {'col': 'y', 'idx': 0.15846796386881423, 'val': 0.9694699984390136},
#     {'col': 'y', 'idx': 0.16738061018970996, 'val': 0.49964390639142064},
#     {'col': 'y', 'idx': 0.052948632283496444, 'val': 0.3606286256267771},
#     {'col': 'y', 'idx': 0.8631001608337633, 'val': 0.016319535581042266},
#     {'col': 'y', 'idx': 0.71190477013045, 'val': 0.8353566111584482},
#     {'col': 'y', 'idx': 0.41697783420333534, 'val': 0.48848988961775386},
#     {'col': 'y', 'idx': 0.992622945021408, 'val': 0.5504602873168912},
#     {'col': 'y', 'idx': 0.60654029609116, 'val': 0.2135551289196589},
#     {'col': 'y', 'idx': 0.33384181722855666, 'val': 0.7688003185821863},
#     {'col': 'y', 'idx': 0.7480882836880633, 'val': 0.30269419616411397},
#     {'col': 'y', 'idx': 0.0056140724461133384, 'val': 0.9438775067009274},
#     {'col': 'y', 'idx': 0.07856007272906196, 'val': 0.3430248139227642},
#     {'col': 'y', 'idx': 0.017990517936890216, 'val': 0.42574058964897976},
#     {'col': 'y', 'idx': 0.5818173073670078, 'val': 0.5094484079140419},
#     {'col': 'y', 'idx': 0.054266859626146635, 'val': 0.6108794309511439},
#     {'col': 'y', 'idx': 0.8709220647821935, 'val': 0.062110056160246785},
#     {'col': 'y', 'idx': 0.01304407152284559, 'val': 0.3425157340404116},
#     {'col': 'y', 'idx': 0.15667517237791084, 'val': 0.4568900144562974},
#     {'col': 'y', 'idx': 0.3540381581712294, 'val': 0.40073506121276137},
#     {'col': 'y', 'idx': 0.3911050337035581, 'val': 0.04548867435607473},
#     {'col': 'y', 'idx': 0.373259450238963, 'val': 0.6890291688378378},
#     {'col': 'y', 'idx': 0.8488332668126322, 'val': 0.3517804581756483},
#     {'col': 'y', 'idx': 0.8328509237866691, 'val': 0.8368110796917582},
#     {'col': 'y', 'idx': 0.6055385300013312, 'val': 0.4032185798079875},
#     {'col': 'y', 'idx': 0.9193895634754345, 'val': 0.6011156283387307},
#     {'col': 'y', 'idx': 0.8801756139192564, 'val': 0.4776870601557176},
#     {'col': 'y', 'idx': 0.6844295955986953, 'val': 0.06552839750854089},
#     {'col': 'y', 'idx': 0.9660596976187573, 'val': 0.13092079466820172},
#     {'col': 'y', 'idx': 0.38748857005747706, 'val': 0.7843944674160004},
#     {'col': 'y', 'idx': 0.5070560857241069, 'val': 0.7756864598179828},
#     {'col': 'y', 'idx': 0.08895711672414586, 'val': 0.8383566525570365},
#     {'col': 'y', 'idx': 0.24752980822188486, 'val': 0.13020638995247835},
#     {'col': 'y', 'idx': 0.12120952010755515, 'val': 0.780036298695481},
#     {'col': 'y', 'idx': 0.7412478164337138, 'val': 0.3455326294260761},
#     {'col': 'y', 'idx': 0.018932650427980535, 'val': 0.48592848485406315},
#     {'col': 'y', 'idx': 0.9942161023662193, 'val': 0.8890478332419804},
#     {'col': 'y', 'idx': 0.14998656970995494, 'val': 0.793369898666587},
#     {'col': 'y', 'idx': 0.6978305465367991, 'val': 0.02492333217245668},
#     {'col': 'y', 'idx': 0.25657440157741696, 'val': 0.20642534885692188},
#     {'col': 'y', 'idx': 0.8693381211560003, 'val': 0.41031232755143643},
#     {'col': 'y', 'idx': 0.2090560928186671, 'val': 0.5811242893013915},
#     {'col': 'y', 'idx': 0.6123184888837967, 'val': 0.720901271307809},
#     {'col': 'y', 'idx': 0.5321129120204725, 'val': 0.5427734078868245},
#     {'col': 'y', 'idx': 0.753733434314938, 'val': 0.4594308043942732},
#     {'col': 'y', 'idx': 0.3091385898713168, 'val': 0.21905000871588765},
#     {'col': 'y', 'idx': 0.6471816302444238, 'val': 0.6894601113889082},
#     {'col': 'y', 'idx': 0.9374826915847619, 'val': 0.4569850002410091}]}],
#  'height': 100,
#  'legends': [],
#  'marks': [{'from': {'data': 'table',
#     'transform': [{'keys': ['data.col'], 'type': 'facet'}]},
#    'marks': [{'properties': {'enter': {'fill': {'field': 'data.col',
#         'scale': 'color'},
#        'size': {'value': 100},
#        'x': {'field': 'data.idx', 'scale': 'x'},
#        'y': {'field': 'data.val', 'scale': 'y'}}},
#      'type': 'symbol'}],
#    'type': 'group'}],
#  'padding': 'auto',
#  'scales': [{'domain': {'data': 'table', 'field': 'data.idx'},
#    'name': 'x',
#    'range': 'width',
#    'type': 'linear'},
#   {'domain': {'data': 'table', 'field': 'data.val'},
#    'name': 'y',
#    'nice': True,
#    'range': 'height'},
#   {'domain': {'data': 'table', 'field': 'data.col'},
#    'name': 'color',
#    'range': 'category20',
#    'type': 'ordinal'}],
#  'width': 200}

# %%
type(data)
# Out:
# dict

# %%
m = folium.Map([0, 0], zoom_start=1)

marker = folium.Marker([0, 0]).add_to(m)
popup = folium.Popup('Hello').add_to(marker)
folium.Vega(data, width='100%', height='100%').add_to(popup)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-2.1.0.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d42a3b1b7388438a8be05624d57f869a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/vega/1.4.3/vega.min.js&quot;&gt;&lt;/script&gt;
#
#             &lt;style&gt; #vega_54fd225a1f44d86057fa5167dd6cf0f8 {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d42a3b1b7388438a8be05624d57f869a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d42a3b1b7388438a8be05624d57f869a = L.map(
#                 &quot;map_d42a3b1b7388438a8be05624d57f869a&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d43495275738bd612e0a5ca6eb41f1f0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d42a3b1b7388438a8be05624d57f869a);
#
#
#             var marker_2f4e3096066f920f3e18d5a608b35c38 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_d42a3b1b7388438a8be05624d57f869a);
#
#     function vega_parse(spec, div) {
#             vg.parse.spec(spec, function(chart) { chart({el:div}).update(); });}
#
#         var popup_7c4ea43ae0692d8dc314e47c079b90cf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_25bfa4c82d8e4ab3c07b7e173657beb6 = $(`&lt;div id=&quot;html_25bfa4c82d8e4ab3c07b7e173657beb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hello&lt;/div&gt;`)[0];
#                 popup_7c4ea43ae0692d8dc314e47c079b90cf.setContent(html_25bfa4c82d8e4ab3c07b7e173657beb6);
#
#
#
#                 var vega_54fd225a1f44d86057fa5167dd6cf0f8 = $(`             &lt;div id=&quot;vega_54fd225a1f44d86057fa5167dd6cf0f8&quot;&gt;&lt;/div&gt;             `)[0];
#                 popup_7c4ea43ae0692d8dc314e47c079b90cf.setContent(vega_54fd225a1f44d86057fa5167dd6cf0f8);
#
#
#
#         marker_2f4e3096066f920f3e18d5a608b35c38.bindPopup(popup_7c4ea43ae0692d8dc314e47c079b90cf)
#         ;
#
#
#
#             vega_parse({&quot;axes&quot;: [{&quot;scale&quot;: &quot;x&quot;, &quot;type&quot;: &quot;x&quot;}, {&quot;scale&quot;: &quot;y&quot;, &quot;type&quot;: &quot;y&quot;}], &quot;data&quot;: [{&quot;name&quot;: &quot;table&quot;, &quot;values&quot;: [{&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.06383443615310558, &quot;val&quot;: 0.8153186625723461}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.4540591918492206, &quot;val&quot;: 0.6571163895553634}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.6896688875570728, &quot;val&quot;: 0.15013444480188132}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.1668974385925398, &quot;val&quot;: 0.9522884586905292}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.7025385623658056, &quot;val&quot;: 0.33394013358031915}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.1468580071397192, &quot;val&quot;: 0.9895969271364038}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.18857028650178675, &quot;val&quot;: 0.17957966055783137}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.07420836523760477, &quot;val&quot;: 0.8304878267979785}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.2828996743338428, &quot;val&quot;: 0.867079060928203}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.16826808472578625, &quot;val&quot;: 0.38265889153811683}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.7454043652204321, &quot;val&quot;: 0.49801379851866523}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.6918938437182678, &quot;val&quot;: 0.735604833695835}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.7428013199056022, &quot;val&quot;: 0.6348958485837621}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.11760668662734708, &quot;val&quot;: 0.6864587417505902}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.014876640370163896, &quot;val&quot;: 0.8779790167604002}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.6103950510059409, &quot;val&quot;: 0.45028030683821696}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.9377712158918619, &quot;val&quot;: 0.7055216967422538}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.48305018087884066, &quot;val&quot;: 0.07350172334173932}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.43757902875978627, &quot;val&quot;: 0.5887256276354502}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.5487611864127908, &quot;va

# %% [markdown]
# ### Vega-Lite chart in popup

# %%
cars = vega_datasets.data.cars()
cars
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# 0         130.0           3504          12.0 1970-01-01     USA
# 1         165.0           3693          11.5 1970-01-01     USA
# 2         150.0           3436          11.0 1970-01-01     USA
# 3         150.0           3433          12.0 1970-01-01     USA
# 4         140.0           3449          10.5 1970-01-01     USA
# ..          ...            ...           ...        ...     ...
# 401        86.0           2790          15.6 1982-01-01     USA
# 402        52.0           2130          24.6 1982-01-01  Europe
# 403        84.0           2295          11.6 1982-01-01     USA
# 404        79.0           2625          18.6 1982-01-01     USA
# 405        82.0           2720          19.4 1982-01-01     USA
#
# [406 rows x 9 columns]

# %%
scatter = (
    Chart(cars)
        .mark_circle()
        .encode(
            x='Horsepower',
            y='Miles_per_Gallon',
            color='Origin'
        )
)

scatter
# Out:
# alt.Chart(...)

# %%
vega_lite = folium.VegaLite(
    scatter,
    width='100%',
    height='100%'
)

vega_lite

# %%
m = folium.Map(location=[-27.5717, -48.6256])

marker = folium.Marker([-27.57, -48.62])
popup = folium.Popup()

vega_lite.add_to(popup)
popup.add_to(marker)
marker.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_613bf85b5d55950aebc47202c6005216 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_0cae99f9cad1305a24cc70a008eb9a09 {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm//vega@5&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/vega-lite@4&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/vega-embed@6&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_613bf85b5d55950aebc47202c6005216&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_613bf85b5d55950aebc47202c6005216 = L.map(
#                 &quot;map_613bf85b5d55950aebc47202c6005216&quot;,
#                 {
#                     center: [-27.5717, -48.6256],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1fcf1fe697d897fc3badb5d71e3ad05 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_613bf85b5d55950aebc47202c6005216);
#
#
#             var marker_eeb0d402f3445896a4acbc247bbb2ba4 = L.marker(
#                 [-27.57, -48.62],
#                 {}
#             ).addTo(map_613bf85b5d55950aebc47202c6005216);
#
#
#         var popup_add7e5c6749f60838b0db724791227fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var vega_lite_0cae99f9cad1305a24cc70a008eb9a09 = $(`             &lt;div id=&quot;vega_lite_0cae99f9cad1305a24cc70a008eb9a09&quot;&gt;&lt;/div&gt;             `)[0];
#                 popup_add7e5c6749f60838b0db724791227fb.setContent(vega_lite_0cae99f9cad1305a24cc70a008eb9a09);
#
#
#
#         marker_eeb0d402f3445896a4acbc247bbb2ba4.bindPopup(popup_add7e5c6749f60838b0db724791227fb)
#         ;
#
#
#
#                     vegaEmbed(vega_lite_0cae99f9cad1305a24cc70a008eb9a09, {&quot;$schema&quot;: &quot;https://vega.github.io/schema/vega-lite/v4.17.0.json&quot;, &quot;config&quot;: {&quot;view&quot;: {&quot;continuousHeight&quot;: 300, &quot;continuousWidth&quot;: 400}}, &quot;data&quot;: {&quot;name&quot;: &quot;data-f02450ab61490a1363517a0190416235&quot;}, &quot;datasets&quot;: {&quot;data-f02450ab61490a1363517a0190416235&quot;: [{&quot;Acceleration&quot;: 12.0, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 307.0, &quot;Horsepower&quot;: 130.0, &quot;Miles_per_Gallon&quot;: 18.0, &quot;Name&quot;: &quot;chevrolet chevelle malibu&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 3504, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 11.5, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 350.0, &quot;Horsepower&quot;: 165.0, &quot;Miles_per_Gallon&quot;: 15.0, &quot;Name&quot;: &quot;buick skylark 320&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 3693, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 11.0, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 318.0, &quot;Horsepower&quot;: 150.0, &quot;Miles_per_Gallon&quot;: 18.0, &quot;Name&quot;: &quot;plymouth satellite&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 3436, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 12.0, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 304.0, &quot;Horsepower&quot;: 150.0, &quot;Miles_per_Gallon&quot;: 16.0, &quot;Name&quot;: &quot;amc rebel sst&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 3433, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 10.5, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 302.0, &quot;Horsepower&quot;: 140.0, &quot;Miles_per_Gallon&quot;: 17.0, &quot;Name&quot;: &quot;ford torino&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 3449, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 10.0, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 429.0, &quot;Horsepower&quot;: 198.0, &quot;Miles_per_Gallon&quot;: 15.0, &quot;Name&quot;: &quot;ford galaxie 500&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 4341, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 9.0, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 454.0, &quot;Horsepower&quot;: 220.0, &quot;Miles_per_Gallon&quot;: 14.0, &quot;Name&quot;: &quot;chevrolet impala&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 4354, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 8.5,

# %% [markdown]
# ### Lazy loading
#
# - for when your popup is slow or you have many popups

# %%
m = folium.Map([43, -100], zoom_start=4)

html = "{a resource that is heavy to load, such as an image}"

folium.Marker([30, -100], popup=html, lazy=True).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dd63f2b78c3a17e417e8ae9d71bf18a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dd63f2b78c3a17e417e8ae9d71bf18a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dd63f2b78c3a17e417e8ae9d71bf18a0 = L.map(
#                 &quot;map_dd63f2b78c3a17e417e8ae9d71bf18a0&quot;,
#                 {
#                     center: [43.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_890f0a27ed666dd5b2c26eca1dc78f0e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dd63f2b78c3a17e417e8ae9d71bf18a0);
#
#
#             var marker_4edae963d58cd7049d0d4dbb0684d196 = L.marker(
#                 [30.0, -100.0],
#                 {&quot;lazy&quot;: true}
#             ).addTo(map_dd63f2b78c3a17e417e8ae9d71bf18a0);
#
#
#         var popup_fbdda2c6012c56f63ba4a222e08bcd77 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd96e916048bdd48eefb03d20075ba81 = $(`&lt;div id=&quot;html_bd96e916048bdd48eefb03d20075ba81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;{a resource that is heavy to load, such as an image}&lt;/div&gt;`)[0];
#                 popup_fbdda2c6012c56f63ba4a222e08bcd77.setContent(html_bd96e916048bdd48eefb03d20075ba81);
#
#
#
#         marker_4edae963d58cd7049d0d4dbb0684d196.bindPopup(popup_fbdda2c6012c56f63ba4a222e08bcd77)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Icons

# %% [markdown]
# ### Rotate icons

# %%
m = folium.Map(location=[41, -71], zoom_start=4)

kw = {'prefix': 'fa',
      'color': 'green',
      'icon': 'arrow-up'}

angle=180
icon = folium.Icon(angle=angle, **kw)
folium.Marker(location=[41, -72], icon=icon, tooltip=str(angle)).add_to(m)

angle=45
icon = folium.Icon(angle=angle, **kw)
folium.Marker(location=[41, -75], icon=icon, tooltip=str(angle)).add_to(m)

angle=90
icon = folium.Icon(angle=angle, **kw)
folium.Marker(location=[41, -78], icon=icon, tooltip=str(angle)).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dfe8ded70a7fdf88d170d606517b10ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dfe8ded70a7fdf88d170d606517b10ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dfe8ded70a7fdf88d170d606517b10ba = L.map(
#                 &quot;map_dfe8ded70a7fdf88d170d606517b10ba&quot;,
#                 {
#                     center: [41.0, -71.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_233ffd4eacc9ca35c79c94b2c289de35 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dfe8ded70a7fdf88d170d606517b10ba);
#
#
#             var marker_ad1b3e1ed1a15d6d90d612b5d4b77ca5 = L.marker(
#                 [41.0, -72.0],
#                 {}
#             ).addTo(map_dfe8ded70a7fdf88d170d606517b10ba);
#
#
#             var icon_f5ac7fdf9b1737e56c5b3f8f5c8661b0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-180&quot;, &quot;icon&quot;: &quot;arrow-up&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ad1b3e1ed1a15d6d90d612b5d4b77ca5.setIcon(icon_f5ac7fdf9b1737e56c5b3f8f5c8661b0);
#
#
#             marker_ad1b3e1ed1a15d6d90d612b5d4b77ca5.bindTooltip(
#                 `&lt;div&gt;
#                      180
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2e01f5e8468573efdf4c79e0270a444f = L.marker(
#                 [41.0, -75.0],
#                 {}
#             ).addTo(map_dfe8ded70a7fdf88d170d606517b10ba);
#
#
#             var icon_1bb668b513245fc887123f6413dc3467 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-45&quot;, &quot;icon&quot;: &quot;arrow-up&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2e01f5e8468573efdf4c79e0270a444f.setIcon(icon_1bb668b513245fc887123f6413dc3467);
#
#
#             marker_2e01f5e8468573efdf4c79e0270a444f.bindTooltip(
#                 `&lt;div&gt;
#                      45
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_aa20ba98b371b440f89ba20d4f9db08e = L.marker(
#                 [41.0, -78.0],
#                 {}
#             ).addTo(map_dfe8ded70a7fdf88d170d606517b10ba);
#
#
#             var icon_b7627ef2c1bf5c3254a5480a1f03fd8b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-90&quot;, &quot;icon&quot;: &quot;arrow-up&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_aa20ba98b371b440f89ba20d4f9db08e.setIcon(icon_b7627ef2c1bf5c3254a5480a1f03fd8b);
#
#
#             marker_aa20ba98b371b440f89ba20d4f9db08e.bindTooltip(
#                 `&lt;div&gt;
#                      90
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Custom icons

# %%
url = "https://leafletjs.com/examples/custom-icons/{}".format
icon_image = url("leaf-red.png")
shadow_image = url("leaf-shadow.png")

# %%
icon_image
# Out:
# 'https://leafletjs.com/examples/custom-icons/leaf-red.png'

# %% [markdown]
# <img src='https://leafletjs.com/examples/custom-icons/leaf-red.png'>

# %%
shadow_image
# Out:
# 'https://leafletjs.com/examples/custom-icons/leaf-shadow.png'

# %% [markdown]
# <img src='https://leafletjs.com/examples/custom-icons/leaf-shadow.png'>

# %%
m = folium.Map(location=[45.3288, -121.6625], zoom_start=12)

icon = folium.CustomIcon(
    icon_image=icon_image,
    icon_size=(38, 95),
    icon_anchor=(22, 94),
    shadow_image=shadow_image,
    shadow_size=(50, 64),
    shadow_anchor=(4, 62),
    popup_anchor=(-3, -76)
)

folium.Marker(
    location=[45.3288, -121.6625],
    icon=icon,
    popup='Mt. Hood Meadows'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef2a0247dce5cd86af1f4860a69c30f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef2a0247dce5cd86af1f4860a69c30f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef2a0247dce5cd86af1f4860a69c30f0 = L.map(
#                 &quot;map_ef2a0247dce5cd86af1f4860a69c30f0&quot;,
#                 {
#                     center: [45.3288, -121.6625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_89aa1352a69792dbc81ab9c18fd50d31 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ef2a0247dce5cd86af1f4860a69c30f0);
#
#
#             var marker_217a4420e25095a0b42294d370edd396 = L.marker(
#                 [45.3288, -121.6625],
#                 {}
#             ).addTo(map_ef2a0247dce5cd86af1f4860a69c30f0);
#
#
#         var custom_icon_f78680570ee91885e083d99c1ee2c0e7 = L.icon({&quot;iconAnchor&quot;: [22, 94], &quot;iconSize&quot;: [38, 95], &quot;iconUrl&quot;: &quot;https://leafletjs.com/examples/custom-icons/leaf-red.png&quot;, &quot;popupAnchor&quot;: [-3, -76], &quot;shadowAnchor&quot;: [4, 62], &quot;shadowSize&quot;: [50, 64], &quot;shadowUrl&quot;: &quot;https://leafletjs.com/examples/custom-icons/leaf-shadow.png&quot;});
#         marker_217a4420e25095a0b42294d370edd396.setIcon(custom_icon_f78680570ee91885e083d99c1ee2c0e7);
#
#
#         var popup_ece2cc8ca0c45a703aaf45be81f99e11 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dc83ee587387613620d24cf47e1dd8fc = $(`&lt;div id=&quot;html_dc83ee587387613620d24cf47e1dd8fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mt. Hood Meadows&lt;/div&gt;`)[0];
#                 popup_ece2cc8ca0c45a703aaf45be81f99e11.setContent(html_dc83ee587387613620d24cf47e1dd8fc);
#
#
#
#         marker_217a4420e25095a0b42294d370edd396.bindPopup(popup_ece2cc8ca0c45a703aaf45be81f99e11)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
